# %% [markdown]
# #STREAMLIT EXECUTION (IDS PROJECT ✈):

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 50.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 49.5 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# Title
st.title("Bank Term Deposit Prediction App")

st.write("This app predicts whether a customer will subscribe to a bank term deposit.")

# Load dataset
df = pd.read_csv("bank.csv")

# Encode categorical variables
for col in df.select_dtypes(include=['object']).columns:
    df[col] = pd.factorize(df[col])[0]

# Features & target
X = df.drop('deposit', axis=1)
y = df['deposit']

# Scale features
X = (X - X.min()) / (X.max() - X.min())

# Train model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X, y)

st.subheader("Enter Customer Details")

# User inputs
age = st.slider("Age", 18, 95, 30)
balance = st.number_input("Account Balance", -2000, 100000, 1000)
duration = st.number_input("Contact Duration (seconds)", 0, 5000, 300)
campaign = st.number_input("Campaign Contacts", 1, 50, 1)

# Create input dataframe
input_data = pd.DataFrame({
    "age": [age],
    "balance": [balance],
    "duration": [duration],
    "campaign": [campaign]
})

# Fill missing columns
for col in X.columns:
    if col not in input_data.columns:
        input_data[col] = 0

input_data = input_data[X.columns]

# Prediction
if st.button("Predict"):
    prediction = model.predict(input_data)[0]
    if prediction == 1:
        st.success("✅ Customer WILL subscribe to the term deposit")
    else:
        st.error("❌ Customer will NOT subscribe to the term deposit")
# Out:
# 2025-12-21 12:45:52.067 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-21 12:45:52.672
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-12-21 12:45:52.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-21 12:45:52.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-21 12:45:52.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-21 12:45:52.682 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-21 12:45:52.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %% [markdown]
# #STREAMLIT EXECUTION NOTE
#
# The Streamlit application was developed to enable real-time predictions
# based on user input. Due to environment limitations of Google Colab,
# the application is intended to be executed using the command
# "streamlit run app.py" in a local environment.
#
# While running inside a notebook environment, Streamlit may generate
# context-related warnings, which do not affect the functionality of
# the application.
